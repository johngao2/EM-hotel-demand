# %%
import pandas as pd
import numpy as np

# %%
trans_df = pd.read_csv('../../../data/cabot_data/sprint_2/trans_s2_raw.csv', index_col=['LOOK_DATE', 'INTRADAY'])

# %%
# reset to number index
trans_df = trans_df.reset_index()
trans_df.index += 1
trans_df
# Out:
#         LOOK_DATE  INTRADAY            PRODUCT
# 1      2018-01-02         1   ('CD', 32, 4, 2)
# 2      2018-01-02         2   ('DD', 25, 4, 2)
# 3      2018-01-02         3   ('DD', 25, 4, 2)
# 4      2018-01-02         4  ('DKB', 39, 4, 3)
# 5      2018-01-02         5   ('DK', 36, 4, 1)
# 6      2018-01-02         6  ('DKB', 39, 4, 3)
# 7      2018-01-02         7  ('4BV', 36, 4, 3)
# 8      2018-01-02         8  ('4BV', 21, 5, 4)
# 9      2018-01-02         9   ('DD', 32, 4, 2)
# 10     2018-01-02        10   ('CK', 25, 4, 2)
# 11     2018-01-02        11   ('CK', 20, 5, 3)
# 12     2018-01-02        12   ('DK', 36, 4, 1)
# 13     2018-01-02        13   ('DK', 32, 4, 1)
# 14     2018-01-02        14   ('CD', 35, 3, 4)
# 15     2018-01-02        15  ('4BV', 36, 4, 3)
# 16     2018-01-02        16   ('DD', 25, 4, 2)
# 17     2018-01-02        17   ('DK', 25, 4, 2)
# 18     2018-01-02        18                NaN
# 19     2018-01-02        19                NaN
# ...
